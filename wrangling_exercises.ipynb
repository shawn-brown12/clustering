# %% [markdown]
# # Wrangling Exercises

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, QuantileTransformer

pd.options.display.max_columns = None

import os
from env import host, username, password
import acquire
import prepare
import wrangle_mall

# %% [markdown]
# For the following, iterate through the steps you would take to create functions: Write the code to do the following in a jupyter notebook, test it, convert to functions, then create the file to house those functions.
#
# You will have a zillow.ipynb file and a helper file for each section in the pipeline.

# %% [markdown]
# ## Zillow Dataset Exercises

# %% [markdown]
# ### Acquire and Summarize
#
# Acquire data from the cloud database.
#
# You will want to end with a single dataframe. Include the logerror field and all other fields related to the properties that are available. You will end up using all the tables in the database.
#
# Be sure to do the correct join (inner, outer, etc.). We do not want to eliminate properties purely because they may have a null value for airconditioningtypeid. - Only include properties with a transaction in 2017, and include only the last transaction for each property (so no duplicate property ID's), along with zestimate error and date of transaction. (Hint: read the docs for the .duplicated method) - Only include properties that have a latitude and longitude value.

# %%
def get_zillow():
    
    if os.path.isfile('zillow_data.csv'):
        
        df = pd.read_csv('zillow_data.csv')
        df = df.drop(columns='Unnamed: 0')

        return df

    else:
        
        url = get_connection('zillow')
        query = '''
                SELECT *
                FROM properties_2017
                LEFT JOIN airconditioningtype USING(airconditioningtypeid)
                LEFT JOIN architecturalstyletype USING(architecturalstyletypeid)
                LEFT JOIN heatingorsystemtype USING(heatingorsystemtypeid)
                LEFT JOIN propertylandusetype USING(propertylandusetypeid)
                LEFT JOIN storytype USING(storytypeid)
                LEFT JOIN typeconstructiontype USING(typeconstructiontypeid)
                LEFT JOIN unique_properties USING(parcelid)
                JOIN predictions_2017 USING(id); 
                '''
        df = pd.read_sql(query, url)                
        df.to_csv('zillow_data.csv')

        return df

# %%
def get_connection(db, user=username, host=host, password=password):
    '''
    This functions imports my credentials for the Codeup MySQL server to be used to pull data
    '''
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

# %%
df = get_zillow()
# Out:
# /var/folders/zk/vf208zwx67vf8nf5b5xtyllw0000gn/T/ipykernel_24404/1415617014.py:5: DtypeWarning: Columns (61,64,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('zillow_data.csv')

# %% [markdown]
# Summarize your data (summary stats, info, dtypes, shape, distributions, value_counts, etc.)

# %%
df.dtypes
# Out:
# id                          int64
# parcelid                    int64
# typeconstructiontypeid    float64
# storytypeid               float64
# propertylandusetypeid     float64
#                            ...
# storydesc                  object
# typeconstructiondesc       object
# parcelid.1                  int64
# logerror                  float64
# transactiondate            object
# Length: 68, dtype: object

# %%
df['typeconstructiontypeid'].isna().sum()
# Out:
# 77448

# %%
df = df[df['transactiondate'].str.startswith('2017')]

# %%
df['latitude'].isna().sum()
# Out:
# 0

# %%
df['longitude'].isna().sum()
# Out:
# 0

# %%
df['id'].nunique()
# Out:
# 77613

# %%
df.describe().T.head()
# Out:
#                           count          mean           std         min  \
# id                      77613.0  3.880600e+04  2.240509e+04         0.0
# parcelid                77613.0  1.337946e+07  8.351498e+06  10711745.0
# typeconstructiontypeid    166.0  5.987952e+00  1.552301e-01         4.0
# storytypeid                45.0  7.000000e+00  0.000000e+00         7.0
# propertylandusetypeid   77613.0  2.599353e+02  1.696527e+01        31.0
#
#                                25%         50%         75%          max
# id                         19403.0     38806.0     58209.0      77612.0
# parcelid                11585740.0  12532258.0  14115107.0  169601949.0
# typeconstructiontypeid         6.0         6.0         6.0          6.0
# storytypeid                    7.0         7.0         7.0          7.0
# propertylandusetypeid        261.0       261.0       261.0        275.0

# %%
df.dtypes
# Out:
# id                          int64
# parcelid                    int64
# typeconstructiontypeid    float64
# storytypeid               float64
# propertylandusetypeid     float64
#                            ...
# storydesc                  object
# typeconstructiondesc       object
# parcelid.1                  int64
# logerror                  float64
# transactiondate            object
# Length: 68, dtype: object

# %%
df.shape
# Out:
# (77613, 68)

# %%
for col in df.columns:
    print ("---- %s ---" % col)
    print (df[col].value_counts())
# Out:
# ---- id ---
# 0        1
# 51748    1
# 51746    1
# 51745    1
# 51744    1
#         ..
# 25871    1
# 25870    1
# 25869    1
# 25868    1
# 77612    1
# Name: id, Length: 77613, dtype: int64
# ---- parcelid ---
# 10754147    1
# 12342442    1
# 12342129    1
# 12341748    1
# 12341725    1
#            ..
# 14005894    1
# 14005825    1
# 14005687    1
# 14005664    1
# 11213162    1
# Name: parcelid, Length: 77613, dtype: int64
# ---- typeconstructiontypeid ---
# 6.0    165
# 4.0      1
# Name: typeconstructiontypeid, dtype: int64
# ---- storytypeid ---
# 7.0    45
# Name: storytypeid, dtype: int64
# ---- propertylandusetypeid ---
# 261.0    56079
# 266.0    12491
# 246.0     2852
# 263.0     1681
# 269.0     1609
# 247.0     1021
# 248.0      980
# 265.0      288
# 31.0       272
# 47.0       144
# 260.0      103
# 267.0       48
# 275.0       35
# 264.0        9
# 270.0        1
# Name: propertylandusetypeid, dtype: int64
# ---- heatingorsystemtypeid ---
# 2.0     30567
# 7.0     16593
# 6.0       662
# 24.0      511
# 20.0       84
# 13.0       38
# 18.0       14
# 12.0        2
# 1.0         2
# 10.0        1
# Name: heatingorsystemtypeid, dtype: int64
# ---- architecturalstyletypeid ---
# 7.0     133
# 8.0      10
# 21.0      5
# 2.0       3
# Name: architecturalstyletypeid, dtype: int64
# ---- airconditioningtypeid ---
# 1.0     19626
# 13.0     1509
# 5.0       219
# 9.0        55
# 11.0       46
# 12.0        1
# Name: airconditioningtypeid, dtype: int64
# ---- basementsqft ---
# 240.0     2
# 216.0     1
# 555.0     1
# 195.0     1
# 544.0     1
# 498.0     1
# 176.0     1
# 360.0     1
# 154.0     1
# 616.0     1
# 1131.0    1
# 200.0     1
# 1016.0    1
# 1089.0    1
# 2443.0    1
# 276.0     1
# 396.0     1
# 149.0     1
# 168.0     1
# 495.0     1
# 208.0     1
# 1035.0    1
# 1572.0    1
# 924.0     1
# 420.0     1
# 224.0     1
# 782.0     1
# 651.0     1
# 516.0     1
# 600.0     1
# 732.0     1
# 1145.0    1
# 220.0     1
# 688.0     1
# 1120.0    1
# 144.0     1
# 540.0     1
# 1312.0    1
# 690.0     1
# 640.0     1
# 550.0     1
# 63.0      1
# 198.0     1
# 560.0     1
# Name: basementsqft, dtype: int64
# ---- bathroomcnt ---
# 2.0     31561
# 3.0     16676
# 1.0     12779
# 2.5      5416
# 4.0      3442
# 0.0      3200
# 1.5      1178
# 5.0      1025
# 3.5       836
# 4.5       519
# 6.0       437
# 5.5       167
# 7.0       161
# 8.0       101
# 9.0        37
# 6.5        30
# 10.0       16
# 7.5        11
# 12.0        7
# 8.5         5
# 11.0        4
# 13.0        1
# 9.5         1
# 14.0        1
# 20.0        1
# 19.5        1
# Name: bathroomcnt, dtype: int64
# ---- bedroomcnt ---
# 3.0     30322
# 4.0     19079
# 2.0     15841
# 5.0      4805
# 0.0      3328
# 1.0      2154
# 6.0      1276
# 8.0       334
# 7.0       278
# 9.0       113
# 10.0       38
# 12.0       26
# 11.0       16
# 14.0        1
# 16.0        1
# 25.0        1
# Name: bedroomcnt, dtype: int64
# ---- buildingclasstypeid ---
# 4.0    300
# 3.0     78
# 2.0      3
# 5.0      1
# 1.0      1
# Name: buildingclasstypeid, dtype: int64
# ---- buildingqualitytypeid ---
# 6.0     14637
# 8.0     13205
# 4.0     11424
# 7.0      4938
# 5.0      2669
# 9.0      1801
# 11.0      735
# 3.0       474
# 10.0      292
# 12.0      108
# 1.0        30
# 2.0         8
# Name: buildingqualitytypeid, dtype: int64
# ---- calculatedbathnbr ---
# 2.0     31561
# 3.0     16676
# 1.0     12778
# 2.5      5406
# 4.0      3442
# 1.5      1171
# 5.0      1025
# 3.5       835
# 4.5       517
# 6.0       437
# 5.5       166
# 7.0       161
# 8.0       101
# 9.0        37
# 6.5        30
# 10.0       16
# 7.5        10
# 12.0        7
# 8.5         5
# 11.0        4
# 13.0        1
# 9.5         1
# 14.0        1
# 20.0        1
# 19.5        1
# Name: calculatedbathnbr, dtype: int64
# ---- decktypeid ---
# 66.0    513
# Name: decktypeid, dtype: int64
# ---- finishedfloor1squarefeet ---
# 1252.0    34
# 1233.0    32
# 1441.0    22
# 725.0     21
# 1218.0    20
#           ..
# 1158.0     1
# 1017.0     1
# 2280.0     1
# 565.0      1
# 3859.0     1
# Name: finishedfloor1squarefeet, Length: 1756, dtype: int64
# ---- calculatedfinishedsquarefeet ---
# 1440.0     209
# 1344.0     190
# 1200.0     176
# 960.0      171
# 1248.0     159
#           ...
# 542.0        1
# 3577.0       1
# 11937.0      1
# 6622.0       1
# 8948.0       1
# Name: calculatedfinishedsquarefeet, Length: 5110, dtype: int64
# ---- finishedsquarefeet12 ---
# 1344.0    171
# 1200.0    166
# 1440.0    164
# 960.0     160
# 1080.0    151
#          ...
# 4401.0      1
# 5932.0      1
# 3627.0      1
# 6181.0      1
# 4466.0      1
# Name: finishedsquarefeet12, Length: 4805, dtype: int64
# ---- finishedsquarefeet13 ---
# 1440.0    38
# 1248.0    19
# 1344.0    17
# 720.0     10
# 1536.0     7
#           ..
# 550.0      1
# 918.0      1
# 1464.0     1
# 900.0      1
# 1215.0     1
# Name: finishedsquarefeet13, Length: 65, dtype: int64
# ---- finishedsquarefeet15 ---
# 1536.0    21
# 1600.0    12
# 1836.0    11
# 2400.0    11
# 2024.0    10
#           ..
# 2241.0     1
# 3500.0     1
# 3007.0     1
# 3818.0     1
# 1770.0     1
# Name: finishedsquarefeet15, Length: 2392, dtype: int64
# ---- finishedsquarefeet50 ---
# 1252.0    34
# 1233.0    32
# 1441.0    22
# 725.0     21
# 1218.0    20
#           ..
# 3204.0     1
# 3105.0     1
# 2033.0     1
# 3215.0     1
# 5894.0     1
# Name: finishedsquarefeet50, Length: 1771, dtype: int64
# ---- finishedsquarefeet6 ---
# 3820.0    4
# 725.0     3
# 816.0     3
# 1056.0    3
# 1750.0    3
#          ..
# 934.0     1
# 1285.0    1
# 4210.0    1
# 4486.0    1
# 3009.0    1
# Name: finishedsquarefeet6, Length: 489, dtype: int64
# ---- fips ---
# 6037.0    52234
# 6059.0    18808
# 6111.0     6571
# Name: fips, dtype: int64
# ---- fireplacecnt ---
# 1.0    7267
# 2.0     914
# 3.0     207
# 4.0      17
# 5.0       4
# 9.0       2
# 7.0       1
# Name: fireplacecnt, dtype: int64
# ---- fullbathcnt ---
# 2.0     36977
# 3.0     17519
# 1.0     13949
# 4.0      3956
# 5.0      1185
# 6.0       464
# 7.0       171
# 8.0       104
# 9.0        36
# 10.0       14
# 12.0        7
# 11.0        4
# 13.0        1
# 14.0        1
# 20.0        1
# 19.0        1
# Name: fullbathcnt, dtype: int64
# ---- garagecarcnt ---
# 2.0     17442
# 1.0      4684
# 3.0       513
# 0.0       361
# 4.0       207
# 5.0        58
# 6.0        13
# 8.0         9
# 7.0         3
# 9.0         3
# 12.0        3
# 11.0        2
# 10.0        1
# 13.0        1
# Name: garagecarcnt, dtype: int64
# ---- garagetotalsqft ---
# 0.0       5274
# 400.0      869
# 360.0      798
# 441.0      714
# 462.0      701
#           ...
# 758.0        1
# 1692.0       1
# 1820.0       1
# 846.0        1
# 979.0        1
# Name: garagetotalsqft, Length: 840, dtype: int64
# ---- hashottuborspa ---
# 1.0    1258
# Name: hashottuborspa, dtype: int64
# ---- latitude ---
# 33984600.0    25
# 33708500.0    22
# 33856782.0    18
# 34169800.0    17
# 34410700.0    16
#               ..
# 33717775.0     1
# 33725524.0     1
# 33656738.0     1
# 33654709.0     1
# 34572200.0     1
# Name: latitude, Length: 67892, dtype: int64
# ---- longitude ---
# -118390000.0    45
# -118389000.0    38
# -118433000.0    38
# -118438000.0    38
# -118436000.0    38
#                 ..
# -117993181.0     1
# -117995172.0     1
# -117993920.0     1
# -117994733.0     1
# -118054267.0     1
# Name: longitude, Length: 66630, dtype: int64
# ---- lotsizesquarefeet ---
# 6000.0      1159
# 5000.0       481
# 7200.0       412
# 7000.0       300
# 6500.0       280
#             ...
# 12947.0        1
# 2283.0         1
# 1120.0         1
# 43734.0        1
# 271458.0       1
# Name: lotsizesquarefeet, Length: 18935, dtype: int64
# ---- poolcnt ---
# 1.0    14261
# Name: poolcnt, dtype: int64
# ---- poolsizesum ---
# 450.0    87
# 800.0    29
# 480.0    25
# 400.0    25
# 500.0    20
#          ..
# 470.0     1
# 441.0     1
# 635.0     1
# 622.0     1
# 216.0     1
# Name: poolsizesum, Length: 241, dtype: int64
# ---- pooltypeid10 ---
# 1.0    424
# Name: pooltypeid10, dtype: int64
# ---- pooltypeid2 ---
# 1.0    834
# Name: pooltypeid2, dtype: int64
# ---- pooltypeid7 ---
# 1.0    13409
# Name: pooltypeid7, dtype: int64
# ---- propertycountylandusecode ---
# 0100    29753
# 122     13114
# 0101     6740
# 010C     5839
# 1111     3697
#         ...
# 105         1
# 030G        1
# 0123        1
# 0140        1
# 120T        1
# Name: propertycountylandusecode, Length: 105, dtype: int64
# ---- propertyzoningdesc ---
# LAR1          7457
# LAR3          1746
# LARS          1580
# LBR1N         1315
# LAR2          1204
#               ...
# SPR2B10000       1
# SOR1VV           1
# RPOH-RS1*        1
# ARR175           1
# PDR3-R3DP*       1
# Name: propertyzoningdesc, Length: 2039, dtype: int64
# ---- rawcensustractandblock ---
# 6.037920e+07    40
# 6.059052e+07    36
# 6.059052e+07    35
# 6.037142e+07    25
# 6.037274e+07    25
#                 ..
# 6.059011e+07     1
# 6.059012e+07     1
# 6.059012e+07     1
# 6.059011e+07     1
# 6.037911e+07     1
# Name: rawcensustractandblock, Length: 47510, dtype: int64
# ---- regionidcity ---
# 12447.0    18015
# 46298.0     2321
# 54311.0     1574
# 16764.0     1500
# 52650.0     1466
#            ...
# 41484.0        2
# 32927.0        2
# 10815.0        2
# 25535.0        1
# 27512.0        1
# Name: regionidcity, Length: 177, dtype: int64
# ---- regionidcounty ---
# 3101.0    52234
# 1286.0    18808
# 2061.0     6571
# Name: regionidcounty, dtype: int64
# ---- regionidneighborhood ---
# 118208.0    788
# 48570.0     625
# 268496.0    571
# 27080.0     569
# 37739.0     545
#            ...
# 276348.0      1
# 47913.0       1
# 764145.0      1
# 764140.0      1
# 762948.0      1
# Name: regionidneighborhood, Length: 494, dtype: int64
# ---- regionidzip ---
# 97118.0    604
# 96368.0    597
# 96987.0    560
# 96193.0    536
# 97318.0    523
#           ...
# 96329.0      5
# 96226.0      4
# 96467.0      1
# 96500.0      1
# 97177.0      1
# Name: regionidzip, Length: 387, dtype: int64
# ---- roomcnt ---
# 0.0     60042
# 6.0      4705
# 7.0      4083
# 8.0      3230
# 5.0      2605
# 9.0      1175
# 4.0      1158
# 10.0      295
# 3.0       167
# 11.0       75
# 12.0       32
# 2.0        22
# 13.0        8
# 14.0        5
# 1.0         4
# 86.0        1
# 15.0        1
# 18.0        1
# 22.0        1
# 19.0        1
# 17.0        1
# Name: roomcnt, dtype: int64
# ---- threequarterbathnbr ---
# 1.0    8138
# 2.0      58
# 4.0       4
# 3.0       4
# Name: threequarterbathnbr, dtype: int64
# ---- unitcnt ---
# 1.0      46370
# 2.0       2886
# 3.0       1030
# 4.0        964
# 5.0         12
# 6.0          3
# 9.0          2
# 11.0         1
# 10.0         1
# 199.0        1
# 21.0         1
# 77.0         1
# 69.0         1
# 18.0         1
# 138.0        1
# 33.0         1
# 8.0          1
# 29.0         1
# 127.0        1
# 35.0         1
# 7.0          1
# 12.0         1
# 16.0         1
# 73.0         1
# 26.0         1
# 22.0         1
# 13.0         1
# 48.0         1
# 36.0         1
# Name: unitcnt, dtype: int64
# ---- yardbuildingsqft17 ---
# 240.0     105
# 200.0      89
# 300.0      66
# 180.0      53
# 288.0      48
#          ...
# 6407.0      1
# 362.0       1
# 267.0       1
# 347.0       1
# 193.0       1
# Name: yardbuildingsqft17, Length: 557, dtype: int64
# ---- yardbuildingsqft26 ---
# 240.0     4
# 100.0     3
# 360.0     2
# 112.0     2
# 432.0     2
# 36.0      2
# 80.0      2
# 30.0      2
# 160.0     2
# 162.0     1
# 187.0     1
# 184.0     1
# 49.0      1
# 235.0     1
# 288.0     1
# 224.0     1
# 196.0     1
# 200.0     1
# 319.0     1
# 1320.0    1
# 169.0     1
# 273.0     1
# 120.0     1
# 46.0      1
# 1497.0    1
# 144.0     1
# 77.0      1
# 504.0     1
# 1280.0    1
# 559.0     1
# 260.0     1
# 425.0     1
# 560.0     1
# 253.0     1
# 26.0      1
# 135.0     1
# 170.0     1
# 96.0      1
# 300.0     1
# 816.0     1
# 704.0     1
# 102.0     1
# 90.0      1
# 56.0      1
# 32.0      1
# 14.0      1
# 192.0     1
# 20.0      1
# 33.0      1
# 540.0     1
# 252.0     1
# 320.0     1
# 140.0     1
# 37.0      1
# Name: yardbuildingsqft26, dtype: int64
# ---- yearbuilt ---
# 1955.0    2271
# 1950.0    1970
# 1954.0    1950
# 1956.0    1779
# 1953.0    1709
#           ...
# 1808.0       1
# 1892.0       1
# 1862.0       1
# 1886.0       1
# 1855.0       1
# Name: yearbuilt, Length: 136, dtype: int64
# ---- numberofstories ---
# 1.0    11266
# 2.0     6445
# 3.0      402
# 4.0        6
# Name: numberofstories, dtype: int64
# ---- fireplaceflag ---
# 1.0    125
# Name: fireplaceflag, dtype: int64
# ---- structuretaxvaluedollarcnt ---
# 106103.0    39
# 100000.0    39
# 200000.0    38
# 104023.0    38
# 105000.0    35
#             ..
# 178182.0     1
# 180864.0     1
# 163722.0     1
# 149452.0     1
# 129566.0     1
# Name: structuretaxvaluedollarcnt, Length: 51974, dtype: int64
# ---- taxvaluedollarcnt ---
# 9.0         38
# 400000.0    38
# 450000.0    37
# 390000.0    35
# 460000.0    34
#             ..
# 302776.0     1
# 272941.0     1
# 395856.0     1
# 306986.0     1
# 148600.0     1
# Name: taxvaluedollarcnt, Length: 55830, dtype: int64
# ---- assessmentyear ---
# 2016.0    77520
# 2015.0       59
# 2014.0       33
# 2003.0        1
# Name: assessmentyear, dtype: int64
# ---- landtaxvaluedollarcnt ---
# 21299.0     88
# 22755.0     64
# 16522.0     61
# 16956.0     59
# 19441.0     58
#             ..
# 118732.0     1
# 221859.0     1
# 116069.0     1
# 427087.0     1
# 29700.0      1
# Name: landtaxvaluedollarcnt, Length: 50622, dtype: int64
# ---- taxamount ---
# 4543.58     6
# 2099.52     4
# 3252.16     4
# 3146.10     4
# 10059.28    4
#            ..
# 3435.18     1
# 6893.00     1
# 6127.98     1
# 1901.58     1
# 2510.53     1
# Name: taxamount, Length: 73420, dtype: int64
# ---- taxdelinquencyflag ---
# Y    1504
# Name: taxdelinquencyflag, dtype: int64
# ---- taxdelinquencyyear ---
# 15.0    702
# 14.0    465
# 13.0    130
# 12.0     66
# 11.0     65
# 10.0     33
# 9.0      26
# 8.0      11
# 7.0       4
# 6.0       2
# Name: taxdelinquencyyear, dtype: int64
# ---- censustractandblock ---
# 6.037920e+13    32
# 6.037142e+13    25
# 6.037277e+13    25
# 6.037920e+13    24
# 6.037920e+13    23
#                 ..
# 6.059002e+13     1
# 6.059002e+13     1
# 6.059011e+13     1
# 6.059012e+13     1
# 6.037911e+13     1
# Name: censustractandblock, Length: 46872, dtype: int64
# ---- airconditioningdesc ---
# Central          19626
# Yes               1509
# None               219
# Refrigeration       55
# Wall Unit           46
# Window Unit          1
# Name: airconditioningdesc, dtype: int64
# ---- architecturalstyledesc ---
# Contemporary     133
# Conventional      10
# Ranch/Rambler      5
# Bungalow           3
# Name: architecturalstyledesc, dtype: int64
# ---- heatingorsystemdesc ---
# Central       30567
# Floor/Wall    16593
# Forced air      662
# Yes             511
# Solar            84
# None             38
# Radiant          14
# Hot Water         2
# Baseboard         2
# Gravity           1
# Name: heatingorsystemdesc, dtype: int64
# ---- propertylandusedesc ---
# Single Family Residential                     56079
# Condominium                                   12491
# Duplex (2 Units, Any Combination)              2852
# Mobile Home                                    1681
# Planned Unit Development                       1609
# Triplex (3 Units, Any Combination)             1021
# Quadruplex (4 Units, Any Combination)           980
# Cluster Home                                    288
# Commercial/Office/Residential Mixed Used        272
# Store/Office (Mixed Use)                        144
# Residential General                             103
# Cooperative                                      48
# Manufactured, Modular, Prefabricated Homes       35
# Townhouse                                         9
# Residential Common Area                           1
# Name: propertylandusedesc, dtype: int64
# ---- storydesc ---
# Basement    45
# Name: storydesc, dtype: int64
# ---- typeconstructiondesc ---
# Frame       165
# Concrete      1
# Name: typeconstructiondesc, dtype: int64
# ---- parcelid.1 ---
# 11991059    3
# 10857130    3
# 12612211    3
# 10984661    2
# 10946379    2
#            ..
# 11446758    1
# 14013599    1
# 13853971    1
# 17128107    1
# 12826780    1
# Name: parcelid.1, Length: 77414, dtype: int64
# ---- logerror ---
#  0.000231    7
#  0.002652    7
#  0.000420    5
#  0.006909    5
#  0.000727    5
#             ..
#  0.018738    1
# -0.062850    1
# -0.000670    1
#  0.063874    1
#  0.037129    1
# Name: logerror, Length: 77064, dtype: int64
# ---- transactiondate ---
# 2017-06-30    1195
# 2017-04-28     917
# 2017-05-31     868
# 2017-07-28     815
# 2017-08-31     782
#               ...
# 2017-03-12       1
# 2017-07-22       1
# 2017-08-05       1
# 2017-08-06       1
# 2017-09-25       1
# Name: transactiondate, Length: 264, dtype: int64

# %%
df.isna().sum()
# Out:
# id                            0
# parcelid                      0
# typeconstructiontypeid    77447
# storytypeid               77568
# propertylandusetypeid         0
#                           ...
# storydesc                 77568
# typeconstructiondesc      77447
# parcelid.1                    0
# logerror                      0
# transactiondate               0
# Length: 68, dtype: int64

# %%
df['typeconstructiontypeid'].value_counts()
# Out:
# 6.0    165
# 4.0      1
# Name: typeconstructiontypeid, dtype: int64

# %% [markdown]
# Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.

# %%
df.dropna(axis='columns', how='any')
# Out:
#           id  parcelid  propertylandusetypeid  bathroomcnt  bedroomcnt  \
# 0          0  10754147                  269.0          0.0         0.0
# 1          1  10759547                  261.0          0.0         0.0
# 2          2  10843547                   47.0          0.0         0.0
# 3          3  10859147                   47.0          0.0         0.0
# 4          4  10879947                   31.0          0.0         0.0
# ...      ...       ...                    ...          ...         ...
# 77609  77609  11212539                  261.0          3.0         4.0
# 77610  77610  11212639                  261.0          3.0         4.0
# 77611  77611  11212962                  261.0          2.0         3.0
# 77612  77612  11213162                  266.0          3.0         3.0
# 77613  77613  11213262                  261.0          3.0         4.0
#
#          fips    latitude    longitude  rawcensustractandblock  \
# 0      6037.0  34144442.0 -118654084.0            6.037800e+07
# 1      6037.0  34140430.0 -118625364.0            6.037800e+07
# 2      6037.0  33989359.0 -118394633.0            6.037703e+07
# 3      6037.0  34148863.0 -118437206.0            6.037141e+07
# 4      6037.0  34194168.0 -118385816.0            6.037123e+07
# ...       ...         ...          ...                     ...
# 77609  6037.0  34572256.0 -118024872.0            6.037911e+07
# 77610  6037.0  34571498.0 -118039412.0            6.037911e+07
# 77611  6037.0  34575327.0 -118054267.0            6.037911e+07
# 77612  6037.0  34572200.0 -118053000.0            6.037911e+07
# 77613  6037.0  34561927.0 -118052811.0            6.037911e+07
#
#        regionidcounty  assessmentyear  \
# 0              3101.0          2016.0
# 1              3101.0          2015.0
# 2              3101.0          2016.0
# 3              3101.0          2016.0
# 4              3101.0          2016.0
# ...               ...             ...
# 77609          3101.0          2016.0
# 77610          3101.0          2016.0
# 77611          3101.0          2016.0
# 77612          3101.0          2016.0
# 77613          3101.0          2016.0
#
#                             propertylandusedesc  parcelid.1  logerror  \
# 0                      Planned Unit Development    14297519  0.025595
# 1                     Single Family Residential    17052889  0.055619
# 2                      Store/Office (Mixed Use)    14186244  0.005383
# 3                      Store/Office (Mixed Use)    12177905 -0.103410
# 4      Commercial/Office/Residential Mixed Used    10887214  0.006940
# ...                                         ...         ...       ...
# 77609                 Single Family Residential    11000655  0.020615
# 77610                 Single Family Residential    17239384  0.013209
# 77611                 Single Family Residential    12773139  0.037129
# 77612                               Condominium    12826780  0.007204
# 77613                 Single Family Residential    13083743 -0.197755
#
#       transactiondate
# 0          2017-01-01
# 1          2017-01-01
# 2          2017-01-01
# 3          2017-01-01
# 4          2017-01-01
# ...               ...
# 77609      2017-09-20
# 77610      2017-09-21
# 77611      2017-09-21
# 77612      2017-09-25
# 77613      2018-05-25
#
# [77614 rows x 15 columns]

# %%
df.isna().sum() / len(df) < .9
# Out:
# id                         True
# parcelid                   True
# typeconstructiontypeid    False
# storytypeid               False
# propertylandusetypeid      True
#                           ...
# storydesc                 False
# typeconstructiondesc      False
# parcelid.1                 True
# logerror                   True
# transactiondate            True
# Length: 68, dtype: bool

# %%
df[col].isna().sum() / len(df[col]) < .9
# Out:
# True

# %%
df['typeconstructiontypeid']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 77609   NaN
# 77610   NaN
# 77611   NaN
# 77612   NaN
# 77613   NaN
# Name: typeconstructiontypeid, Length: 77614, dtype: float64

# %%
if df[col].isna().sum() / len(df[col]) < .9:
            
    df = df.dropna(axis=1, thresh=20000)

# %%
for col in df.columns:
    
    if df[col].isna().sum() / len(df[col]) < .9:
            
        df = df.dropna(axis=1)
        
    else:
        
        return df
# Out:
#   Input In [120]
#     return df
#     ^
# SyntaxError: 'return' outside function

# %%
df
# Out:
#           id  parcelid  propertylandusetypeid  bathroomcnt  bedroomcnt  \
# 0          0  10754147                  269.0          0.0         0.0
# 1          1  10759547                  261.0          0.0         0.0
# 2          2  10843547                   47.0          0.0         0.0
# 3          3  10859147                   47.0          0.0         0.0
# 4          4  10879947                   31.0          0.0         0.0
# ...      ...       ...                    ...          ...         ...
# 77609  77609  11212539                  261.0          3.0         4.0
# 77610  77610  11212639                  261.0          3.0         4.0
# 77611  77611  11212962                  261.0          2.0         3.0
# 77612  77612  11213162                  266.0          3.0         3.0
# 77613  77613  11213262                  261.0          3.0         4.0
#
#          fips    latitude    longitude  rawcensustractandblock  \
# 0      6037.0  34144442.0 -118654084.0            6.037800e+07
# 1      6037.0  34140430.0 -118625364.0            6.037800e+07
# 2      6037.0  33989359.0 -118394633.0            6.037703e+07
# 3      6037.0  34148863.0 -118437206.0            6.037141e+07
# 4      6037.0  34194168.0 -118385816.0            6.037123e+07
# ...       ...         ...          ...                     ...
# 77609  6037.0  34572256.0 -118024872.0            6.037911e+07
# 77610  6037.0  34571498.0 -118039412.0            6.037911e+07
# 77611  6037.0  34575327.0 -118054267.0            6.037911e+07
# 77612  6037.0  34572200.0 -118053000.0            6.037911e+07
# 77613  6037.0  34561927.0 -118052811.0            6.037911e+07
#
#        regionidcounty  assessmentyear  \
# 0              3101.0          2016.0
# 1              3101.0          2015.0
# 2              3101.0          2016.0
# 3              3101.0          2016.0
# 4              3101.0          2016.0
# ...               ...             ...
# 77609          3101.0          2016.0
# 77610          3101.0          2016.0
# 77611          3101.0          2016.0
# 77612          3101.0          2016.0
# 77613          3101.0          2016.0
#
#                             propertylandusedesc  parcelid.1  logerror  \
# 0                      Planned Unit Development    14297519  0.025595
# 1                     Single Family Residential    17052889  0.055619
# 2                      Store/Office (Mixed Use)    14186244  0.005383
# 3                      Store/Office (Mixed Use)    12177905 -0.103410
# 4      Commercial/Office/Residential Mixed Used    10887214  0.006940
# ...                                         ...         ...       ...
# 77609                 Single Family Residential    11000655  0.020615
# 77610                 Single Family Residential    17239384  0.013209
# 77611                 Single Family Residential    12773139  0.037129
# 77612                               Condominium    12826780  0.007204
# 77613                 Single Family Residential    13083743 -0.197755
#
#       transactiondate
# 0          2017-01-01
# 1          2017-01-01
# 2          2017-01-01
# 3          2017-01-01
# 4          2017-01-01
# ...               ...
# 77609      2017-09-20
# 77610      2017-09-21
# 77611      2017-09-21
# 77612      2017-09-25
# 77613      2018-05-25
#
# [77614 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['id', 'parcelid', 'propertylandusetypeid', 'bathroomcnt', 'bedroomcnt',
#        'fips', 'latitude', 'longitude', 'rawcensustractandblock',
#        'regionidcounty', 'assessmentyear', 'propertylandusedesc', 'parcelid.1',
#        'logerror', 'transactiondate'],
#       dtype='object')

# %%
def prep_zillow(df):
    
    for col in df:
        
        if df.isna().sum() / len(df) < .6:
            
            df.dropna(axis=1)
            
    prop_required_col = 
    
    prop_required_row =

# %%
df.dropna(axis=0, thresh=.75)
# Out:
#           id  parcelid  typeconstructiontypeid  storytypeid  \
# 0          0  10754147                     NaN          NaN
# 1          1  10759547                     NaN          NaN
# 2          2  10843547                     NaN          NaN
# 3          3  10859147                     NaN          NaN
# 4          4  10879947                     NaN          NaN
# ...      ...       ...                     ...          ...
# 77609  77609  11212539                     NaN          NaN
# 77610  77610  11212639                     NaN          NaN
# 77611  77611  11212962                     NaN          NaN
# 77612  77612  11213162                     NaN          NaN
# 77613  77613  11213262                     NaN          NaN
#
#        propertylandusetypeid  heatingorsystemtypeid  architecturalstyletypeid  \
# 0                      269.0                    NaN                       NaN
# 1                      261.0                    NaN                       NaN
# 2                       47.0                    NaN                       NaN
# 3                       47.0                    NaN                       NaN
# 4                       31.0                    NaN                       NaN
# ...                      ...                    ...                       ...
# 77609                  261.0                    2.0                       NaN
# 77610                  261.0                    2.0                       NaN
# 77611                  261.0                    2.0                       NaN
# 77612                  266.0                    2.0                       NaN
# 77613                  261.0                    2.0                       NaN
#
#        airconditioningtypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 0                        NaN           NaN          0.0         0.0
# 1                        NaN           NaN          0.0         0.0
# 2                        NaN           NaN          0.0         0.0
# 3                        NaN           NaN          0.0         0.0
# 4                        NaN           NaN          0.0         0.0
# ...                      ...           ...          ...         ...
# 77609                    1.0           NaN          3.0         4.0
# 77610                    1.0           NaN          3.0         4.0
# 77611                    1.0           NaN          2.0         3.0
# 77612                    1.0           NaN          3.0         3.0
# 77613                    1.0           NaN          3.0         4.0
#
#        buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  \
# 0                      NaN                    NaN                NaN
# 1                      NaN                    NaN                NaN
# 2                      5.0                    NaN                NaN
# 3                      3.0                    6.0                NaN
# 4                      4.0                    NaN                NaN
# ...                    ...                    ...                ...
# 77609                  NaN                    8.0                3.0
# 77610                  NaN                    8.0                3.0
# 77611                  NaN                    6.0                2.0
# 77612                  NaN                    8.0                3.0
# 77613                  NaN                    8.0                3.0
#
#        decktypeid  finishedfloor1squarefeet  calculatedfinishedsquarefeet  \
# 0             NaN                       NaN                           NaN
# 1             NaN                       NaN                           NaN
# 2             NaN                       NaN                       73026.0
# 3             NaN                       NaN                        5068.0
# 4             NaN                       NaN                        1776.0
# ...           ...                       ...                           ...
# 77609         NaN                       NaN                        1921.0
# 77610         NaN                       NaN                        1780.0
# 77611         NaN                       NaN                        1549.0
# 77612         NaN                       NaN                        1339.0
# 77613         NaN                       NaN                        2059.0
#
#        finishedsquarefeet12  finishedsquarefeet13  finishedsquarefeet15  \
# 0                       NaN                   NaN                   NaN
# 1                       NaN                   NaN                   NaN
# 2                       NaN                   NaN               73026.0
# 3                       NaN                   NaN                5068.0
# 4                       NaN                   NaN                1776.0
# ...                     ...                   ...                   ...
# 77609                1921.0                   NaN                   NaN
# 77610                1780.0                   NaN                   NaN
# 77611                1549.0                   NaN                   NaN
# 77612                1339.0                   NaN                   NaN
# 77613                2059.0                   NaN                   NaN
#
#        finishedsquarefeet50  finishedsquarefeet6    fips  fireplacecnt  \
# 0                       NaN                  NaN  6037.0           NaN
# 1                       NaN                  NaN  6037.0           NaN
# 2                       NaN                  NaN  6037.0           NaN
# 3                       NaN                  NaN  6037.0           NaN
# 4                       NaN                  NaN  6037.0           NaN
# ...                     ...                  ...     ...           ...
# 77609                   NaN                  NaN  6037.0           NaN
# 77610                   NaN                  NaN  6037.0           NaN
# 77611                   NaN                  NaN  6037.0           NaN
# 77612                   NaN                  NaN  6037.0           NaN
# 77613                   NaN                  NaN  6037.0           NaN
#
#        fullbathcnt  garagecarcnt  garagetotalsqft  hashottuborspa    latitude  \
# 0              NaN           NaN              NaN             NaN  34144442.0
# 1              NaN           NaN              NaN             NaN  34140430.0
# 2              NaN           NaN              NaN             NaN  33989359.0
# 3              NaN           NaN              NaN             NaN  34148863.0
# 4              NaN           NaN              NaN             NaN  34194168.0
# ...            ...           ...              ...             ...         ...
# 77609          3.0           NaN              NaN             NaN  34572256.0
# 77610          3.0           NaN              NaN             NaN  34571498.0
# 77611          2.0           NaN              NaN             NaN  34575327.0
# 77612          3.0           NaN              NaN             NaN  34572200.0
# 77613          3.0           NaN              NaN             NaN  34561927.0
#
#          longitude  lotsizesquarefeet  poolcnt  poolsizesum  pooltypeid10  \
# 0     -118654084.0            85768.0      NaN          NaN           NaN
# 1     -118625364.0             4083.0      NaN          NaN           NaN
# 2     -118394633.0            63085.0      NaN          NaN           NaN
# 3     -118437206.0             7521.0      NaN          NaN           NaN
# 4     -118385816.0             8512.0      NaN          NaN           NaN
# ...            ...                ...      ...          ...           ...
# 77609 -118024872.0             6763.0      NaN          NaN           NaN
# 77610 -118039412.0             6822.0      NaN          NaN           NaN
# 77611 -118054267.0             6987.0      NaN          NaN           NaN
# 77612 -118053000.0           271458.0      NaN          NaN           NaN
# 77613 -118052811.0             7021.0      NaN          NaN           NaN
#
#        pooltypeid2  pooltypeid7 propertycountylandusecode propertyzoningdesc  \
# 0              NaN          NaN                      010D                NaN
# 1              NaN          NaN                      0109             LCA11*
# 2              NaN          NaN                      1200               LAC2
# 3              NaN          NaN                      1200               LAC2
# 4              NaN          NaN                      1210               LAM1
# ...            ...          ...                       ...                ...
# 77609          NaN          NaN                      0100             PDA21*
# 77610          NaN          NaN                      0100             PDA21*
# 77611          NaN          NaN                      0100              PDR1*
# 77612          NaN          NaN                      010C         PDR3-R3DP*
# 77613          NaN          NaN                      0100           LCRA7OOO
#
#        rawcensustractandblock  regionidcity  regionidcounty  \
# 0                6.037800e+07       37688.0          3101.0
# 1                6.037800e+07       37688.0          3101.0
# 2                6.037703e+07       51617.0          3101.0
# 3                6.037141e+07       12447.0          3101.0
# 4                6.037123e+07       12447.0          3101.0
# ...                       ...           ...             ...
# 77609            6.037911e+07       40227.0          3101.0
# 77610            6.037911e+07       40227.0          3101.0
# 77611            6.037911e+07       40227.0          3101.0
# 77612            6.037911e+07       40227.0          3101.0
# 77613            6.037911e+07       40227.0          3101.0
#
#        regionidneighborhood  regionidzip  roomcnt  threequarterbathnbr  \
# 0                       NaN      96337.0      0.0                  NaN
# 1                       NaN      96337.0      0.0                  NaN
# 2                       NaN      96095.0      0.0                  NaN
# 3                   27080.0      96424.0      0.0                  NaN
# 4                   46795.0      96450.0      0.0                  NaN
# ...                     ...          ...      ...                  ...
# 77609                   NaN      97330.0      0.0                  NaN
# 77610                   NaN      97330.0      0.0                  NaN
# 77611                   NaN      97330.0      0.0                  NaN
# 77612                   NaN      97330.0      0.0                  NaN
# 77613                   NaN      97330.0      0.0                  NaN
#
#        unitcnt  yardbuildingsqft17  yardbuildingsqft26  yearbuilt  \
# 0          NaN                 NaN                 NaN        NaN
# 1          NaN                 NaN                 NaN        NaN
# 2          2.0                 NaN                 NaN     1959.0
# 3          NaN                 NaN                 NaN     1948.0
# 4          1.0                 NaN                 NaN     1947.0
# ...        ...                 ...                 ...        ...
# 77609      1.0                 NaN                 NaN     1990.0
# 77610      1.0                 NaN                 NaN     1989.0
# 77611      1.0                 NaN                 NaN     1990.0
# 77612      1.0                 NaN                 NaN     1990.0
# 77613      1.0                 NaN                 NaN     1990.0
#
#        numberofstories  fireplaceflag  structuretaxvaluedollarcnt  \
# 0                  NaN            NaN                         NaN
# 1                  NaN            NaN                         NaN
# 2                  1.0            NaN                    660680.0
# 3                  1.0            NaN                    580059.0
# 4                  1.0            NaN                    196751.0
# ...                ...            ...                         ...
# 77609              NaN            NaN                    129566.0
# 77610              NaN            NaN                    100744.0
# 77611              NaN            NaN                    149241.0
# 77612              NaN            NaN                    118900.0
# 77613              NaN            NaN                    104239.0
#
#        taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0                    9.0          2016.0                    9.0        NaN
# 1                27516.0          2015.0                27516.0        NaN
# 2              1434941.0          2016.0               774261.0   20800.37
# 3              1174475.0          2016.0               594416.0   14557.57
# 4               440101.0          2016.0               243350.0    5725.17
# ...                  ...             ...                    ...        ...
# 77609           162019.0          2016.0                32453.0    2860.33
# 77610           125923.0          2016.0                25179.0    2394.26
# 77611           198988.0          2016.0                49747.0    3331.81
# 77612           148600.0          2016.0                29700.0    2510.53
# 77613           130296.0          2016.0                26057.0    2470.35
#
#       taxdelinquencyflag  taxdelinquencyyear  censustractandblock  \
# 0                    NaN                 NaN                  NaN
# 1                    NaN                 NaN                  NaN
# 2                    NaN                 NaN                  NaN
# 3                    NaN                 NaN                  NaN
# 4                    NaN                 NaN                  NaN
# ...                  ...                 ...                  ...
# 77609                NaN                 NaN         6.037911e+13
# 77610                NaN                 NaN         6.037911e+13
# 77611                NaN                 NaN         6.037911e+13
# 77612                NaN                 NaN         6.037911e+13
# 77613                  Y                10.0         6.037911e+13
#
#       airconditioningdesc architecturalstyledesc heatingorsystemdesc  \
# 0                     NaN                    NaN                 NaN
# 1                     NaN                    NaN                 NaN
# 2                     NaN                    NaN                 NaN
# 3                     NaN                    NaN                 NaN
# 4                     NaN                    NaN                 NaN
# ...                   ...                    ...                 ...
# 77609             Central                    NaN             Central
# 77610             Central                    NaN             Central
# 77611             Central                    NaN             Central
# 77612             Central                    NaN             Central
# 77613             Central                    NaN             Central
#
#                             propertylandusedesc storydesc  \
# 0                      Planned Unit Development       NaN
# 1                     Single Family Residential       NaN
# 2                      Store/Office (Mixed Use)       NaN
# 3                      Store/Office (Mixed Use)       NaN
# 4      Commercial/Office/Residential Mixed Used       NaN
# ...                                         ...       ...
# 77609                 Single Family Residential       NaN
# 77610                 Single Family Residential       NaN
# 77611                 Single Family Residential       NaN
# 77612                               Condominium       NaN
# 77613                 Single Family Residential       NaN
#
#       typeconstructiondesc  parcelid.1  logerror transactiondate
# 0                      NaN    14297519  0.025595      2017-01-01
# 1                      NaN    17052889  0.055619      2017-01-01
# 2                      NaN    14186244  0.005383      2017-01-01
# 3                      NaN    12177905 -0.103410      2017-01-01
# 4                      NaN    10887214  0.006940      2017-01-01
# ...                    ...         ...       ...             ...
# 77609                  NaN    11000655  0.020615      2017-09-20
# 77610                  NaN    17239384  0.013209      2017-09-21
# 77611                  NaN    12773139  0.037129      2017-09-21
# 77612                  NaN    12826780  0.007204      2017-09-25
# 77613                  NaN    13083743 -0.197755      2018-05-25
#
# [77614 rows x 68 columns]

# %%
df.head()
# Out:
#    id  parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0   0  10754147                     NaN          NaN                  269.0
# 1   1  10759547                     NaN          NaN                  261.0
# 2   2  10843547                     NaN          NaN                   47.0
# 3   3  10859147                     NaN          NaN                   47.0
# 4   4  10879947                     NaN          NaN                   31.0
#
#    heatingorsystemtypeid  architecturalstyletypeid  airconditioningtypeid  \
# 0                    NaN                       NaN                    NaN
# 1                    NaN                       NaN                    NaN
# 2                    NaN                       NaN                    NaN
# 3                    NaN                       NaN                    NaN
# 4                    NaN                       NaN                    NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0           NaN          0.0         0.0                  NaN
# 1           NaN          0.0         0.0                  NaN
# 2           NaN          0.0         0.0                  5.0
# 3           NaN          0.0         0.0                  3.0
# 4           NaN          0.0         0.0                  4.0
#
#    buildingqualitytypeid  calculatedbathnbr  decktypeid  \
# 0                    NaN                NaN         NaN
# 1                    NaN                NaN         NaN
# 2                    NaN                NaN         NaN
# 3                    6.0                NaN         NaN
# 4                    NaN                NaN         NaN
#
#    finishedfloor1squarefeet  calculatedfinishedsquarefeet  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                       73026.0
# 3                       NaN                        5068.0
# 4                       NaN                        1776.0
#
#    finishedsquarefeet12  finishedsquarefeet13  finishedsquarefeet15  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN               73026.0
# 3                   NaN                   NaN                5068.0
# 4                   NaN                   NaN                1776.0
#
#    finishedsquarefeet50  finishedsquarefeet6    fips  fireplacecnt  \
# 0                   NaN                  NaN  6037.0           NaN
# 1                   NaN                  NaN  6037.0           NaN
# 2                   NaN                  NaN  6037.0           NaN
# 3                   NaN                  NaN  6037.0           NaN
# 4                   NaN                  NaN  6037.0           NaN
#
#    fullbathcnt  garagecarcnt  garagetotalsqft  hashottuborspa    latitude  \
# 0          NaN           NaN              NaN             NaN  34144442.0
# 1          NaN           NaN              NaN             NaN  34140430.0
# 2          NaN           NaN              NaN             NaN  33989359.0
# 3          NaN           NaN              NaN             NaN  34148863.0
# 4          NaN           NaN              NaN             NaN  34194168.0
#
#      longitude  lotsizesquarefeet  poolcnt  poolsizesum  pooltypeid10  \
# 0 -118654084.0            85768.0      NaN          NaN           NaN
# 1 -118625364.0             4083.0      NaN          NaN           NaN
# 2 -118394633.0            63085.0      NaN          NaN           NaN
# 3 -118437206.0             7521.0      NaN          NaN           NaN
# 4 -118385816.0             8512.0      NaN          NaN           NaN
#
#    pooltypeid2  pooltypeid7 propertycountylandusecode propertyzoningdesc  \
# 0          NaN          NaN                      010D                NaN
# 1          NaN          NaN                      0109             LCA11*
# 2          NaN          NaN                      1200               LAC2
# 3          NaN          NaN                      1200               LAC2
# 4          NaN          NaN                      1210               LAM1
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidneighborhood  \
# 0            6.037800e+07       37688.0          3101.0                   NaN
# 1            6.037800e+07       37688.0          3101.0                   NaN
# 2            6.037703e+07       51617.0          3101.0                   NaN
# 3            6.037141e+07       12447.0          3101.0               27080.0
# 4            6.037123e+07       12447.0          3101.0               46795.0
#
#    regionidzip  roomcnt  threequarterbathnbr  unitcnt  yardbuildingsqft17  \
# 0      96337.0      0.0                  NaN      NaN                 NaN
# 1      96337.0      0.0                  NaN      NaN                 NaN
# 2      96095.0      0.0                  NaN      2.0                 NaN
# 3      96424.0      0.0                  NaN      NaN                 NaN
# 4      96450.0      0.0                  NaN      1.0                 NaN
#
#    yardbuildingsqft26  yearbuilt  numberofstories  fireplaceflag  \
# 0                 NaN        NaN              NaN            NaN
# 1                 NaN        NaN              NaN            NaN
# 2                 NaN     1959.0              1.0            NaN
# 3                 NaN     1948.0              1.0            NaN
# 4                 NaN     1947.0              1.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2016.0
# 1                         NaN            27516.0          2015.0
# 2                    660680.0          1434941.0          2016.0
# 3                    580059.0          1174475.0          2016.0
# 4                    196751.0           440101.0          2016.0
#
#    landtaxvaluedollarcnt  taxamount taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                NaN                 NaN
# 1                27516.0        NaN                NaN                 NaN
# 2               774261.0   20800.37                NaN                 NaN
# 3               594416.0   14557.57                NaN                 NaN
# 4               243350.0    5725.17                NaN                 NaN
#
#    censustractandblock airconditioningdesc architecturalstyledesc  \
# 0                  NaN                 NaN                    NaN
# 1                  NaN                 NaN                    NaN
# 2                  NaN                 NaN                    NaN
# 3                  NaN                 NaN                    NaN
# 4                  NaN                 NaN                    NaN
#
#   heatingorsystemdesc                       propertylandusedesc storydesc  \
# 0                 NaN                  Planned Unit Development       NaN
# 1                 NaN                 Single Family Residential       NaN
# 2                 NaN                  Store/Office (Mixed Use)       NaN
# 3                 NaN                  Store/Office (Mixed Use)       NaN
# 4                 NaN  Commercial/Office/Residential Mixed Used       NaN
#
#   typeconstructiondesc  parcelid.1  logerror transactiondate  percent_missing
# 0                  NaN    14297519  0.025595      2017-01-01              NaN
# 1                  NaN    17052889  0.055619      2017-01-01              NaN
# 2                  NaN    14186244  0.005383      2017-01-01              NaN
# 3                  NaN    12177905 -0.103410      2017-01-01              NaN
# 4                  NaN    10887214  0.006940      2017-01-01              NaN

# %%
def missing_values(df):
    
    null_df = df.isna().sum().reset_index()

    null_df['percent_missing'] = (null_df[0] / len(df)) * 100
    
    null_df = null_df.rename(columns= {'index':'attributes',
                                        0: 'num_missing'})                
    return null_df

# %%
missing_values(df)
# Out:
#                 attributes  num_missing  percent_missing
# 0                       id            0         0.000000
# 1                 parcelid            0         0.000000
# 2   typeconstructiontypeid        77448        99.786121
# 3              storytypeid        77569        99.942021
# 4    propertylandusetypeid            0         0.000000
# ..                     ...          ...              ...
# 64    typeconstructiondesc        77448        99.786121
# 65              parcelid.1            0         0.000000
# 66                logerror            0         0.000000
# 67         transactiondate            0         0.000000
# 68         percent_missing        77614       100.000000
#
# [69 rows x 3 columns]

# %% [markdown]
# ### Prepare

# %% [markdown]
# Remove any properties that are likely to be something other than single unit properties. (e.g. no duplexes, no land/lot, ...). There are multiple ways to estimate that a property is a single unit, and there is not a single "right" answer.

# %%
df = df[df['propertylandusetypeid'] == 261]

# %% [markdown]
# Create a function that will drop rows or columns based on the percent of values that are missing: handle_missing_values(df, prop_required_column, prop_required_row).
#
# - The input:
#     - A dataframe
#     - A number between 0 and 1 that represents the proportion, for each column, of rows with non-missing values required to keep the column. i.e. if prop_required_column = .6, then you are requiring a column to have at least 60% of values not-NA (no more than 40% missing).
#     - A number between 0 and 1 that represents the proportion, for each row, of columns/variables with non-missing values required to keep the row. For example, if prop_required_row = .75, then you are requiring a row to have at least 75% of variables with a non-missing value (no more that 25% missing).
# - The output:
#     - The dataframe with the columns and rows dropped as indicated. Be sure to drop the columns prior to the rows in your function.
# - hint:
#     - Look up the dropna documentation.
#     - You will want to compute a threshold from your input values (prop_required) and total number of rows or columns.

# %%
df.isna().sum()
# Out:
# id                            0
# parcelid                      0
# typeconstructiontypeid    77448
# storytypeid               77569
# propertylandusetypeid         0
#                           ...
# typeconstructiondesc      77448
# parcelid.1                    0
# logerror                      0
# transactiondate               0
# percent_missing           77614
# Length: 69, dtype: int64

# %%
def prep_zillow(df, col_p=.6, row_p=.75):
    
    null_df = df.isna().sum().reset_index()

    null_df['percent_missing'] = (df[0] / len(df)) * 100

# %% [markdown]
# Encapsulate your work inside of functions in a wrangle_zillow.py module.

# %% [markdown]
# ### Mall Customers Exercises

# %% [markdown]
#  Acquire data from the customers table in the mall_customers database.

# %%
mall = acquire.get_mall_customers()

# %% [markdown]
# Summarize the data (include distributions and descriptive statistics).

# %%
mall.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40

# %%
mall.describe().T
# Out:
#                 count    mean        std   min    25%    50%     75%    max
# customer_id     200.0  100.50  57.879185   1.0  50.75  100.5  150.25  200.0
# age             200.0   38.85  13.969007  18.0  28.75   36.0   49.00   70.0
# annual_income   200.0   60.56  26.264721  15.0  41.50   61.5   78.00  137.0
# spending_score  200.0   50.20  25.823522   1.0  34.75   50.0   73.00   99.0

# %%
mall.dtypes
# Out:
# customer_id        int64
# gender            object
# age                int64
# annual_income      int64
# spending_score     int64
# dtype: object

# %%
mall.isna().sum()
# Out:
# customer_id       0
# gender            0
# age               0
# annual_income     0
# spending_score    0
# dtype: int64

# %% [markdown]
# Detect outliers using IQR.

# %%
my_list = ['age', 'annual_income', 'spending_score']

prepare.remove_outliers(mall, 1.5, my_list)
# Out:
#      customer_id  gender  age  annual_income  spending_score
# 0              1    Male   19             15              39
# 1              2    Male   21             15              81
# 2              3  Female   20             16               6
# 3              4  Female   23             16              77
# 4              5  Female   31             17              40
# ..           ...     ...  ...            ...             ...
# 193          194  Female   38            113              91
# 194          195  Female   47            120              16
# 195          196  Female   35            120              79
# 196          197  Female   45            126              28
# 197          198    Male   32            126              74
#
# [198 rows x 5 columns]

# %% [markdown]
# Split data into train, validate, and test.

# %%
train, validate, test = prepare.subset_df(mall)
# Out:
# (120, 5) (40, 5) (40, 5)

# %% [markdown]
# Encode categorical columns using a one hot encoder (pd.get_dummies).

# %%
def wrangle_mall_df(outlier_k=1.5):
    
    df = get_mall_customers()
    df = df.dropna()
    
    cont_list = ['age', 'annual_income', 'spending_score']
    cat_list = ['gender']

    df = remove_outliers(df, 1.5, my_list) 
    df = pd.get_dummies(df, cat_list)
    
    train, validate, test = subset_df(df)
    
    return train, validate, test

# %%
train, validate, test = wrangle_mall.wrangle_mall_df()
# Out:
# (118, 6) (40, 6) (40, 6)

# %% [markdown]
# Handles missing values.

# %%
train.dropna()
# Out:
#      customer_id  age  annual_income  spending_score  gender_Female  \
# 22            23   46             25               5              1
# 148          149   34             78              22              1
# 146          147   48             77              36              0
# 33            34   18             33              92              0
# 11            12   35             19              99              1
# ..           ...  ...            ...             ...            ...
# 106          107   66             63              50              1
# 14            15   37             20              13              0
# 92            93   48             60              49              0
# 179          180   35             93              90              0
# 102          103   67             62              59              0
#
#      gender_Male
# 22             0
# 148            0
# 146            1
# 33             1
# 11             0
# ..           ...
# 106            0
# 14             1
# 92             1
# 179            1
# 102            1
#
# [118 rows x 6 columns]

# %%
train.isna().sum()
# Out:
# customer_id       0
# age               0
# annual_income     0
# spending_score    0
# gender_Female     0
# gender_Male       0
# dtype: int64

# %% [markdown]
# Scaling

# %%
to_scale = ['age', 'annual_income', 'spending_score']

train_scaled, validate_scaled, test_scaled = prepare.scale_data(train, validate, test, MinMaxScaler(), to_scale)

# %%
train_scaled.head()
# Out:
#      customer_id       age  annual_income  spending_score  gender_Female  \
# 2              3  0.038462       0.008197        0.051020              1
# 77            78  0.423077       0.319672        0.479592              0
# 46            47  0.615385       0.204918        0.551020              1
# 187          188  0.192308       0.704918        0.683673              0
# 191          192  0.269231       0.721311        0.693878              1
#
#      gender_Male
# 2              0
# 77             1
# 46             0
# 187            1
# 191            0

# %% [markdown]
# Encapsulate your work in a wrangle_mall.py python module.

# %% [markdown]
# # Class Review takeaways

# %%
df = get_zillow()
# Out:
# /var/folders/zk/vf208zwx67vf8nf5b5xtyllw0000gn/T/ipykernel_24404/1415617014.py:5: DtypeWarning: Columns (61,64,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('zillow_data.csv')

# %%
def null_counter(df):
    
    new_cols = ['name', 'num_rows_missing', 'percent_rows_missing'] 
    new_df = pd.DataFrame(columns=new_cols)
    
    for columns in df.columns:
        
        num_missing = df[col].isna().sum()
        pct_missing = num_missing / df.shape[0]
        
        add_df = pd.DataFrame([{'name': col,
                                'num_rows_missing': num_missing,
                                'percent_rows_missing': pct_missing}])
        new_df = pd.concat([new_df, add_df], axis=0)
        
    new_df.set_index('name', inplace=True)
    
    return new_df

# %%
new_df = null_counter(df)

# %%
new_df
# Out:
#                 num_rows_missing  percent_rows_missing
# name
# transactiondate                0                   0.0
# transactiondate                0                   0.0
# transactiondate                0                   0.0
# transactiondate                0                   0.0
# transactiondate                0                   0.0
# ...                          ...                   ...
# transactiondate                0                   0.0
# transactiondate                0                   0.0
# transactiondate                0                   0.0
# transactiondate                0                   0.0
# transactiondate                0                   0.0
#
# [69 rows x 2 columns]

# %%
def drop(df, thresh1, thresh2):
    
    loop = list(range(0, len(df.axes[1])))
    adf = []
    
    for i in loop:
        
        x = df.iloc[:,i].isna().sum()
        adf.append(x)
        
    fjf = []
    
    for i in adf:
        
        x = i / len(df.axes[0])
        fjf.append(x)
        
    indices = np.array(fjf)
    indices2 = np.where(indices > thresh1)[0]
    
    df = df.drop(df.columns[indices2], axis = 1)
    
    ddd = []
    
    x = df.isna().sum(axis=1) 
    
    for i in x:
        
        you = i /len(x)
        ddd.append(you)
        
    indices3 = np.where(ddd)
    indices4 = np.where(indices > thresh2)[0]
        
    drop = df.drop(indices4)
    
    return df

# %%
df1 = drop(df, .6, .5)

df1.isna().sum()
# Out:
# Unnamed: 0                          0
# id                                  0
# parcelid                            0
# propertylandusetypeid               0
# heatingorsystemtypeid           29139
# bathroomcnt                         0
# bedroomcnt                          0
# buildingqualitytypeid           27292
# calculatedbathnbr                3223
# calculatedfinishedsquarefeet     1112
# finishedsquarefeet12             6650
# fips                                0
# fullbathcnt                      3223
# latitude                            0
# longitude                           0
# lotsizesquarefeet                7079
# propertycountylandusecode           1
# propertyzoningdesc              26252
# rawcensustractandblock              0
# regionidcity                     1526
# regionidcounty                      0
# regionidzip                       275
# roomcnt                             1
# unitcnt                         26324
# yearbuilt                        1170
# structuretaxvaluedollarcnt       1265
# taxvaluedollarcnt                 925
# assessmentyear                      0
# landtaxvaluedollarcnt            1611
# taxamount                         511
# censustractandblock              2095
# heatingorsystemdesc             29139
# propertylandusedesc                 0
# parcelid.1                          0
# logerror                            0
# transactiondate                     0
# dtype: int64

# %%
cols = mall.columns.to_list()

for col in cols:
    
    plt.hist(mall)
    plt.show()

# %%
mall['age'].quantile([.25, .75])
# Out:
# 0.25    28.75
# 0.75    49.00
# Name: age, dtype: float64

# %%
q1, q3 = np.percentile(mall['age'], [25, 75])

q1, q3
# Out:
# (28.75, 49.0)
