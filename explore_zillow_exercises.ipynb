# %% [markdown]
# # Exploring Zillow Exercises

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as stats

import wrangle_zillow

pd.options.display.max_columns = None

# %% [markdown]
# Sourcing the Zillow database as the data source, create a jupyter notebook named explore_zillow and do the following:
#
# - Ask at least 5 questions about the data, keeping in mind that your target variable is logerror. e.g. Is logerror significantly different for properties in LA County vs Orange County vs Ventura County?
#
#
# - Answer those questions through a mix of statistical tests and visualizations.

# %%
df = wrangle_zillow.get_zillow()
# Out:
# /Users/shawnbrown/codeup-data-science/clustering/wrangle_zillow.py:27: DtypeWarning: Columns (61,64,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('zillow_data.csv')

# %%
df
# Out:
#           id  parcelid  typeconstructiontypeid  storytypeid  \
# 0          0  10754147                     NaN          NaN
# 1          1  10759547                     NaN          NaN
# 2          2  10843547                     NaN          NaN
# 3          3  10859147                     NaN          NaN
# 4          4  10879947                     NaN          NaN
# ...      ...       ...                     ...          ...
# 77609  77609  11212539                     NaN          NaN
# 77610  77610  11212639                     NaN          NaN
# 77611  77611  11212962                     NaN          NaN
# 77612  77612  11213162                     NaN          NaN
# 77613  77613  11213262                     NaN          NaN
#
#        propertylandusetypeid  heatingorsystemtypeid  architecturalstyletypeid  \
# 0                      269.0                    NaN                       NaN
# 1                      261.0                    NaN                       NaN
# ...

# %%
df['architecturalstyledesc'].isna().sum()
# Out:
# 77463

# %%
def drop(df, thresh1, thresh2):
    
    loop = list(range(0, len(df.axes[1])))
    adf = []
    
    for i in loop:
        
        x = df.iloc[:,i].isna().sum()
        adf.append(x)
        
    fjf = []
    
    for i in adf:
        
        x = i / len(df.axes[0])
        fjf.append(x)
        
    indices = np.array(fjf)
    indices2 = np.where(indices > thresh1)[0]
    
    df = df.drop(df.columns[indices2], axis = 1)
    
    ddd = []
    
    x = df.isna().sum(axis=1) 
    
    for i in x:
        
        you = i /len(x)
        ddd.append(you)
        
    indices3 = np.where(ddd)
    indices4 = np.where(indices > thresh2)[0]
        
    df = df.drop(indices4)
    
    return df

# %%
df = drop(df, .6, .75)

# %%
df
# Out:
#           id  parcelid  propertylandusetypeid  heatingorsystemtypeid  \
# 0          0  10754147                  269.0                    NaN
# 1          1  10759547                  261.0                    NaN
# 4          4  10879947                   31.0                    NaN
# 5          5  10898347                   31.0                    NaN
# 7          7  10940747                   31.0                    NaN
# ...      ...       ...                    ...                    ...
# 77609  77609  11212539                  261.0                    2.0
# 77610  77610  11212639                  261.0                    2.0
# 77611  77611  11212962                  261.0                    2.0
# 77612  77612  11213162                  266.0                    2.0
# 77613  77613  11213262                  261.0                    2.0
#
#        bathroomcnt  bedroomcnt  buildingqualitytypeid  calculatedbathnbr  \
# ...

# %%
train, validate, test = wrangle_zillow.subset_df(df)
# Out:
# (46551, 35) (15517, 35) (15518, 35)
